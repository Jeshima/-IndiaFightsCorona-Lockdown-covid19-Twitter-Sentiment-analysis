# %%
import tweepy
import jsonpickle
import csv
import time
st = time.time()
API_KEY="jsU0a5IcdcEcleXmyrnAcQW1fxy"
API_SECRET="pYO1KsrMvHmzBeMvAVDZLRWRETWUb3vXHUKTWP6NMGzpOuerCG"

auth = tweepy.AppAuthHandler(API_KEY,API_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
#wait_on_rate_limit – Whether or not to automatically wait for rate limits to replenish
#wait_on_rate_limit_notify – Whether or not to print a notification when Tweepy is waiting for rate limits to replenish
# the sleep mode is automatically enabled with above 2 args


tweetsPerQuery = 10000#this is the maximum provided by API
max_tweets = 100000 # just for the sake of While loop
fName = 'co.txt' # where i save the tweets

# No sinceId and max_id ..Get whathever you have exhaustively
since_id = None
max_id = -1
tweet_count = 0
print("Downloading the tweeets..takes some time..")

search_query="#covid19"
x=0
with open(fName,'w') as f:
    print("Downloading hashtag" + search_query)
    while(tweet_count<max_tweets):
        try:
            if(max_id<=0):
                if(not since_id):
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended')

                else:
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended',since_id=since_id)
            else:
                if(not since_id):
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended',max_id=str(max_id-1))
                else:
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended',max_id=str(max_id-1),since_id=since_id)

            # Tweets Exhausted
            if(not new_tweets):
                print("No more tweets found!!")
                break
            # write all the new_tweets to a json file
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json,unpicklable=False)+'\n')
                tweet_count+=len(new_tweets)
                print("Successfully downloaded {0} tweets".format(tweet_count))
                max_id=new_tweets[-1].id
        # in case of any error
        except tweepy.TweepError as e:
                print("Some error!!:"+str(e))
                break
end = time.time()

print("A total of {0} tweets are downloaded and saved to {1}".format(tweet_count,fName))
print("Total time taken is ",end-st,"seconds.")
# Out:
# Downloading the tweeets..takes some time..
# Downloading hashtag#covid19
# Successfully downloaded 97 tweets
# Successfully downloaded 194 tweets
# Successfully downloaded 291 tweets
# Successfully downloaded 388 tweets
# Successfully downloaded 485 tweets
# Successfully downloaded 582 tweets
# Successfully downloaded 679 tweets
# Successfully downloaded 776 tweets
# Successfully downloaded 873 tweets
# Successfully downloaded 970 tweets
# Successfully downloaded 1067 tweets
# Successfully downloaded 1164 tweets
# Successfully downloaded 1261 tweets
# Successfully downloaded 1358 tweets
# Successfully downloaded 1455 tweets
# Successfully downloaded 1552 tweets
# Successfully downloaded 1649 tweets
# Successfully downloaded 1746 tweets
# Successfully downloaded 1843 tweets
# Successfully downloaded 1940 tweets
# Successfully downloaded 2037 tweets
# Successfully downloaded 2134 tweets
# Successfully downloaded 2231 tweets
# Successfully downloaded 2328 tweets
# Successfully downloaded 2425 tweets
# Successfully downloaded 2522 tweets
# Successfully downloaded 2619 tweets
# Successfully downloaded 2716 tweets
# Successfully downloaded 2813 tweets
# Successfully downloaded 2910 tweets
# Successfully downloaded 3007 tweets
# Successfully downloaded 3104 tweets
# Successfully downloaded 3201 tweets
# Successfully downloaded 3298 tweets
# Successfully downloaded 3395 tweets
# Successfully downloaded 3492 tweets
# Successfully downloaded 3589 tweets
# Successfully downloaded 3686 tweets
# Successfully downloaded 3783 tweets
# Successfully downloaded 3880 tweets
# Successfully downloaded 3977 tweets
# Successfully downloaded 4074 tweets
# Successfully downloaded 4171 tweets
# Successfully downloaded 4268 tweets
# Successfully downloaded 4365 tweets
# Successfully downloaded 4462 tweets
# Successfully downloaded 4559 tweets
# Successfully downloaded 4656 tweets
# Successfully downloaded 4753 tweets
# Successfully downloaded 4850 tweets
# Successfully downloaded 4947 tweets
# Successfully downloaded 5044 tweets
# Successfully downloaded 5141 tweets
# Successfully downloaded 5238 tweets
# Successfully downloaded 5335 tweets
# Successfully downloaded 5432 tweets
# Successfully downloaded 5529 tweets
# Successfully downloaded 5626 tweets
# Successfully downloaded 5723 tweets
# Successfully downloaded 5820 tweets
# Successfully downloaded 5917 tweets
# Successfully downloaded 6014 tweets
# Successfully downloaded 6111 tweets
# Successfully downloaded 6208 tweets
# Successfully downloaded 6305 tweets
# Successfully downloaded 6402 tweets
# Successfully downloaded 6499 tweets
# Successfully downloaded 6596 tweets
# Successfully downloaded 6693 tweets
# Successfully downloaded 6790 tweets
# Successfully downloaded 6887 tweets
# Successfully downloaded 6984 tweets
# Successfully downloaded 7081 tweets
# Successfully downloaded 7178 tweets
# Successfully downloaded 7275 tweets
# Successfully downloaded 7372 tweets
# Successfully downloaded 7469 tweets
# Successfully downloaded 7566 tweets
# Successfully downloaded 7663 tweets
# Successfully downloaded 7760 tweets
# Successfully downloaded 7857 tweets
# Successfully downloaded 7954 tweets
# Successfully downloaded 8051 tweets
# Successfully downloaded 8148 tweets
# Successfully downloaded 8245 tweets
# Successfully downloaded 8342 tweets
# Successfully downloaded 8439 tweets
# Successfully downloaded 8536 tweets
# Successfully downloaded 8633 tweets
# Successfully downloaded 8730 tweets
# Successfully downloaded 8827 tweets
# Successfully downloaded 8924 tweets
# Successfully downloaded 9021 tweets
# Successfully downloaded 9118 tweets
# Successfully downloaded 9215 tweets
# Successfully downloaded 9312 tweets
# Successfully downloaded 9409 tweets
# Successfully downloaded 9509 tweets
# Successfully downloaded 9609 tweets
# Successfully downloaded 9709 tweets
# Successfully downloaded 9809 tweets
# Successfully downloaded 9909 tweets
# Successfully downloaded 10009 tweets
# Successfully downloaded 10109 tweets
# Successfully downloaded 10209 tweets
# Successfully downloaded 10309 tweets
# Successfully downloaded 10409 tweets
# Successfully downloaded 10509 tweets
# Successfully downloaded 10609 tweets
# Successfully downloaded 10709 tweets
# Successfully downloaded 10809 tweets
# Successfully downloaded 10909 tweets
# Successfully downloaded 11009 tweets
# Successfully downloaded 11109 tweets
# Successfully downloaded 11209 tweets
# Successfully downloaded 11309 tweets
# Successfully downloaded 11409 tweets
# Successfully downloaded 11509 tweets
# Successfully downloaded 11609 tweets
# Successfully downloaded 11709 tweets
# Successfully downloaded 11809 tweets
# Successfully downloaded 11909 tweets
# Successfully downloaded 12009 tweets
# Successfully downloaded 12109 tweets
# Successfully downloaded 12209 tweets
# Successfully downloaded 12309 tweets
# Successfully downloaded 12409 tweets
# Successfully downloaded 12509 tweets
# Successfully downloaded 12609 tweets
# Successfully downloaded 12709 tweets
# Successfully downloaded 12809 tweets
# Successfully downloaded 12909 tweets
# Successfully downloaded 13009 tweets
# Successfully downloaded 13109 tweets
# Successfully downloaded 13209 tweets
# Successfully downloaded 13309 tweets
# Successfully downloaded 13409 tweets
# Successfully downloaded 13509 tweets
# Successfully downloaded 13609 tweets
# Successfully downloaded 13709 tweets
# Successfully downloaded 13809 tweets
# Successfully downloaded 13909 tweets
# Successfully downloaded 14009 tweets
# Successfully downloaded 14109 tweets
# Successfully downloaded 14209 tweets
# Successfully downloaded 14309 tweets
# Successfully downloaded 14409 tweets
# Successfully downloaded 14509 tweets
# Successfully downloaded 14609 tweets
# Successfully downloaded 14709 tweets
# Successfully downloaded 14809 tweets
# Successfully downloaded 14909 tweets
# Successfully downloaded 15009 tweets
# Successfully downloaded 15109 tweets
# Successfully downloaded 15209 tweets
# Successfully downloaded 15309 tweets
# Successfully downloaded 15409 tweets
# Successfully downloaded 15509 tweets
# Successfully downloaded 15609 tweets
# Successfully downloaded 15709 tweets
# Successfully downloaded 15809 tweets
# Successfully downloaded 15909 tweets
# Successfully downloaded 16009 tweets
# Successfully downloaded 16109 tweets
# Successfully downloaded 16209 tweets
# Successfully downloaded 16309 tweets
# Successfully downloaded 16409 tweets
# Successfully downloaded 16509 tweets
# Successfully downloaded 16609 tweets
# Successfully downloaded 16709 tweets
# Successfully downloaded 16809 tweets
# Successfully downloaded 16909 tweets
# Successfully downloaded 17009 tweets
# Successfully downloaded 17109 tweets
# Successfully downloaded 17209 tweets
# Successfully downloaded 17309 tweets
# Successfully downloaded 17409 tweets
# Successfully downloaded 17509 tweets
# Successfully downloaded 17609 tweets
# Successfully downloaded 17709 tweets
# Successfully downloaded 17809 tweets
# Successfully downloaded 17909 tweets
# Successfully downloaded 18009 tweets
# Successfully downloaded 18109 tweets
# Successfully downloaded 18209 tweets
# Successfully downloaded 18309 tweets
# Successfully downloaded 18409 tweets
# Successfully downloaded 18509 tweets
# Successfully downloaded 18609 tweets
# Successfully downloaded 18709 tweets
# Successfully downloaded 18809 tweets
# Successfully downloaded 18909 tweets
# Successfully downloaded 19009 tweets
# Successfully downloaded 19109 tweets
# Successfully downloaded 19209 tweets
# Successfully downloaded 19309 tweets
# Successfully downloaded 19409 tweets
# Successfully downloaded 19509 tweets
# Successfully downloaded 19609 tweets
# Successfully downloaded 19709 tweets
# Successfully downloaded 19809 tweets
# Successfully downloaded 19909 tweets
# Successfully downloaded 20009 tweets
# Successfully downloaded 20109 tweets
# Successfully downloaded 20209 tweets
# Successfully downloaded 20309 tweets
# Successfully downloaded 20409 tweets
# Successfully downloaded 20509 tweets
# Successfully downloaded 20609 tweets
# Successfully downloaded 20709 tweets
# Successfully downloaded 20809 tweets
# Successfully downloaded 20909 tweets
# Successfully downloaded 21009 tweets
# Successfully downloaded 21109 tweets
# Successfully downloaded 21209 tweets
# Successfully downloaded 21309 tweets
# Successfully downloaded 21409 tweets
# Successfully downloaded 21509 tweets
# Successfully downloaded 21609 tweets
# Successfully downloaded 21709 tweets
# Successfully downloaded 21809 tweets
# Successfully downloaded 21909 tweets
# Successfully downloaded 22009 tweets
# Successfully downloaded 22109 tweets
# Successfully downloaded 22209 tweets
# Successfully downloaded 22309 tweets
# Successfully downloaded 22409 tweets
# Successfully downloaded 22509 tweets
# Successfully downloaded 22609 tweets
# Successfully downloaded 22709 tweets
# Successfully downloaded 22809 tweets
# Successfully downloaded 22909 tweets
# Successfully downloaded 23009 tweets
# Successfully downloaded 23109 tweets
# Successfully downloaded 23209 tweets
# Successfully downloaded 23309 tweets
# Successfully downloaded 23409 tweets
# Successfully downloaded 23509 tweets
# Successfully downloaded 23609 tweets
# Successfully downloaded 23709 tweets
# Successfully downloaded 23809 tweets
# Successfully downloaded 23909 tweets
# Successfully downloaded 24009 tweets
# Successfully downloaded 24109 tweets
# Successfully downloaded 24209 tweets
# Successfully downloaded 24309 tweets
# Successfully downloaded 24409 tweets
# Successfully downloaded 24509 tweets
# Successfully downloaded 24609 tweets
# Successfully downloaded 24709 tweets
# Successfully downloaded 24809 tweets
# Successfully downloaded 24909 tweets
# Successfully downloaded 25009 tweets
# Successfully downloaded 25109 tweets
# Successfully downloaded 25209 tweets
# Successfully downloaded 25309 tweets
# Successfully downloaded 25409 tweets
# Successfully downloaded 25509 tweets
# Successfully downloaded 25609 tweets
# Successfully downloaded 25709 tweets
# Successfully downloaded 25809 tweets
# Successfully downloaded 25909 tweets
# Successfully downloaded 26009 tweets
# Successfully downloaded 26109 tweets
# Successfully downloaded 26209 tweets
# Successfully downloaded 26309 tweets
# Successfully downloaded 26409 tweets
# Successfully downloaded 26509 tweets
# Successfully downloaded 26609 tweets
# Successfully downloaded 26709 tweets
# Successfully downloaded 26809 tweets
# Successfully downloaded 26909 tweets
# Successfully downloaded 27009 tweets
# Successfully downloaded 27109 tweets
# Successfully downloaded 27209 tweets
# Successfully downloaded 27309 tweets
# Successfully downloaded 27409 tweets
# Successfully downloaded 27509 tweets
# Successfully downloaded 27609 tweets
# Successfully downloaded 27709 tweets
# Successfully downloaded 27809 tweets
# Successfully downloaded 27909 tweets
# Successfully downloaded 28009 tweets
# Successfully downloaded 28109 tweets
# Successfully downloaded 28209 tweets
# Successfully downloaded 28309 tweets
# Successfully downloaded 28409 tweets
# Successfully downloaded 28509 tweets
# Successfully downloaded 28609 tweets
# Successfully downloaded 28709 tweets
# Successfully downloaded 28809 tweets
# Successfully downloaded 28909 tweets
# Successfully downloaded 29009 tweets
# Successfully downloaded 29109 tweets
# Successfully downloaded 29209 tweets
# Successfully downloaded 29309 tweets
# Successfully downloaded 29409 tweets
# Successfully downloaded 29509 tweets
# Successfully downloaded 29609 tweets
# Successfully downloaded 29709 tweets
# Successfully downloaded 29809 tweets
# Successfully downloaded 29909 tweets
# Successfully downloaded 30009 tweets
# Successfully downloaded 30109 tweets
# Successfully downloaded 30209 tweets
# Successfully downloaded 30309 tweets
# Successfully downloaded 30409 tweets
# Successfully downloaded 30509 tweets
# Successfully downloaded 30609 tweets
# Successfully downloaded 30709 tweets
# Successfully downloaded 30809 tweets
# Successfully downloaded 30909 tweets
# Successfully downloaded 31009 tweets
# Successfully downloaded 31109 tweets
# Successfully downloaded 31209 tweets
# Successfully downloaded 31309 tweets
# Successfully downloaded 31409 tweets
# Successfully downloaded 31509 tweets
# Successfully downloaded 31609 tweets
# Successfully downloaded 31709 tweets
# Successfully downloaded 31809 tweets
# Successfully downloaded 31909 tweets
# Successfully downloaded 32009 tweets
# Successfully downloaded 32109 tweets
# Successfully downloaded 32209 tweets
# Successfully downloaded 32309 tweets
# Successfully downloaded 32409 tweets
# Successfully downloaded 32509 tweets
# Successfully downloaded 32609 tweets
# Successfully downloaded 32709 tweets
# Successfully downloaded 32809 tweets
# Successfully downloaded 32909 tweets
# Successfully downloaded 33009 tweets
# Successfully downloaded 33109 tweets
# Successfully downloaded 33209 tweets
# Successfully downloaded 33309 tweets
# Successfully downloaded 33409 tweets
# Successfully downloaded 33509 tweets
# Successfully downloaded 33609 tweets
# Successfully downloaded 33709 tweets
# Successfully downloaded 33809 tweets
# Successfully downloaded 33909 tweets
# Successfully downloaded 34009 tweets
# Successfully downloaded 34109 tweets
# Successfully downloaded 34209 tweets
# Successfully downloaded 34309 tweets
# Successfully downloaded 34409 tweets
# Successfully downloaded 34509 tweets
# Successfully downloaded 34609 tweets
# Successfully downloaded 34709 tweets
# Successfully downloaded 34809 tweets
# Successfully downloaded 34909 tweets
# Successfully downloaded 35009 tweets
# Successfully downloaded 35109 tweets
# Successfully downloaded 35209 tweets
# Successfully downloaded 35309 tweets
# Successfully downloaded 35409 tweets
# Successfully downloaded 35509 tweets
# Successfully downloaded 35609 tweets
# Successfully downloaded 35709 tweets
# Successfully downloaded 35809 tweets
# Successfully downloaded 35909 tweets
# Successfully downloaded 36009 tweets
# Successfully downloaded 36109 tweets
# Successfully downloaded 36209 tweets
# Successfully downloaded 36309 tweets
# Successfully downloaded 36409 tweets
# Successfully downloaded 36509 tweets
# Successfully downloaded 36609 tweets
# Successfully downloaded 36709 tweets
# Successfully downloaded 36809 tweets
# Successfully downloaded 36909 tweets
# Successfully downloaded 37009 tweets
# Successfully downloaded 37109 tweets
# Successfully downloaded 37209 tweets
# Successfully downloaded 37309 tweets
# Successfully downloaded 37409 tweets
# Successfully downloaded 37509 tweets
# Successfully downloaded 37609 tweets
# Successfully downloaded 37709 tweets
# Successfully downloaded 37809 tweets
# Successfully downloaded 37909 tweets
# Successfully downloaded 38009 tweets
# Successfully downloaded 38109 tweets
# Successfully downloaded 38209 tweets
# Successfully downloaded 38309 tweets
# Successfully downloaded 38409 tweets
# Successfully downloaded 38509 tweets
# Successfully downloaded 38609 tweets
# Successfully downloaded 38709 tweets
# Successfully downloaded 38809 tweets
# Successfully downloaded 38909 tweets
# Successfully downloaded 39009 tweets
# Successfully downloaded 39109 tweets
# Successfully downloaded 39209 tweets
# Successfully downloaded 39309 tweets
# Successfully downloaded 39409 tweets
# Successfully downloaded 39509 tweets
# Successfully downloaded 39609 tweets
# Successfully downloaded 39709 tweets
# Successfully downloaded 39809 tweets
# Successfully downloaded 39909 tweets
# Successfully downloaded 40009 tweets
# Successfully downloaded 40109 tweets
# Successfully downloaded 40209 tweets
# Successfully downloaded 40309 tweets
# Successfully downloaded 40409 tweets
# Successfully downloaded 40509 tweets
# Successfully downloaded 40609 tweets
# Successfully downloaded 40709 tweets
# Successfully downloaded 40809 tweets
# Successfully downloaded 40909 tweets
# Successfully downloaded 41009 tweets
# Successfully downloaded 41109 tweets
# Successfully downloaded 41209 tweets
# Successfully downloaded 41309 tweets
# Successfully downloaded 41409 tweets
# Successfully downloaded 41509 tweets
# Successfully downloaded 41609 tweets
# Successfully downloaded 41709 tweets
# Successfully downloaded 41809 tweets
# Successfully downloaded 41909 tweets
# Successfully downloaded 42009 tweets
# Successfully downloaded 42109 tweets
# Successfully downloaded 42209 tweets
# Successfully downloaded 42309 tweets
# Successfully downloaded 42409 tweets
# Successfully downloaded 42509 tweets
# Successfully downloaded 42609 tweets
# Successfully downloaded 42709 tweets
# Successfully downloaded 42809 tweets
# Successfully downloaded 42909 tweets
# Successfully downloaded 43009 tweets
# Successfully downloaded 43109 tweets
# Successfully downloaded 43209 tweets
# Successfully downloaded 43309 tweets
# Successfully downloaded 43409 tweets
# Successfully downloaded 43509 tweets
# Successfully downloaded 43609 tweets
# Successfully downloaded 43709 tweets
# Successfully downloaded 43809 tweets
# Successfully downloaded 43909 tweets
# Successfully downloaded 44009 tweets
# Successfully downloaded 44109 tweets
# Successfully downloaded 44209 tweets
# Successfully downloaded 44309 tweets
# Successfully downloaded 44409 tweets
# Successfully downloaded 44509 tweets
# Successfully downloaded 44609 tweets
# Successfully downloaded 44709 tweets
# Successfully downloaded 44809 tweets
# Successfully downloaded 44909 tweets
# Successfully downloaded 45009 tweets
# Successfully downloaded 45109 tweets
# Successfully downloaded 45209 tweets
# Successfully downloaded 45309 tweets
# Successfully downloaded 45409 tweets
# Successfully downloaded 45509 tweets
# Successfully downloaded 45609 tweets
# Successfully downloaded 45709 tweets
# Successfully downloaded 45809 tweets
# Successfully downloaded 45909 tweets
# Successfully downloaded 46009 tweets
# Successfully downloaded 46109 tweets
# Successfully downloaded 46209 tweets
# Successfully downloaded 46309 tweets
# Successfully downloaded 46409 tweets
# Successfully downloaded 46509 tweets
# Successfully downloaded 46609 tweets
# Successfully downloaded 46709 tweets
# Successfully downloaded 46809 tweets
# Successfully downloaded 46909 tweets
# Successfully downloaded 47009 tweets
# Successfully downloaded 47109 tweets
# Successfully downloaded 47209 tweets
# Successfully downloaded 47309 tweets
# Successfully downloaded 47409 tweets
# Successfully downloaded 47509 tweets
# Successfully downloaded 47609 tweets
# Successfully downloaded 47709 tweets
# Successfully downloaded 47809 tweets
# Successfully downloaded 47909 tweets
# Successfully downloaded 48009 tweets
# Successfully downloaded 48109 tweets
# Successfully downloaded 48209 tweets
# Successfully downloaded 48309 tweets
# Successfully downloaded 48409 tweets
# Successfully downloaded 48509 tweets
# Successfully downloaded 48609 tweets
# Successfully downloaded 48709 tweets
# Successfully downloaded 48809 tweets
# Successfully downloaded 48909 tweets
# Successfully downloaded 49009 tweets
# Successfully downloaded 49109 tweets
# Successfully downloaded 49209 tweets
# Successfully downloaded 49309 tweets
# Successfully downloaded 49409 tweets
# Successfully downloaded 49509 tweets
# Successfully downloaded 49609 tweets
# Successfully downloaded 49709 tweets
# Successfully downloaded 49809 tweets
# Successfully downloaded 49909 tweets
# Successfully downloaded 50009 tweets
# Successfully downloaded 50109 tweets
# Successfully downloaded 50209 tweets
# Successfully downloaded 50309 tweets
# Successfully downloaded 50409 tweets
# Successfully downloaded 50509 tweets
# Successfully downloaded 50609 tweets
# Successfully downloaded 50709 tweets
# Successfully downloaded 50809 tweets
# Successfully downloaded 50909 tweets
# Successfully downloaded 51009 tweets
# Successfully downloaded 51109 tweets
# Successfully downloaded 51209 tweets
# Successfully downloaded 51309 tweets
# Successfully downloaded 51409 tweets
# Successfully downloaded 51509 tweets
# Successfully downloaded 51609 tweets
# Successfully downloaded 51709 tweets
# Successfully downloaded 51809 tweets
# Successfully downloaded 51909 tweets
# Successfully downloaded 52009 tweets
# Successfully downloaded 52109 tweets
# Successfully downloaded 52209 tweets
# Successfully downloaded 52309 tweets
# Successfully downloaded 52409 tweets
# Successfully downloaded 52509 tweets
# Successfully downloaded 52609 tweets
# Successfully downloaded 52709 tweets
# Successfully downloaded 52809 tweets
# Successfully downloaded 52909 tweets
# Successfully downloaded 53009 tweets
# Successfully downloaded 53109 tweets
# Successfully downloaded 53209 tweets
# Successfully downloaded 53309 tweets
# Successfully downloaded 53409 tweets
# Successfully downloaded 53509 tweets
# Successfully downloaded 53609 tweets
# Successfully downloaded 53709 tweets
# Successfully downloaded 53809 tweets
# Successfully downloaded 53909 tweets
# Successfully downloaded 54009 tweets
# Successfully downloaded 54109 tweets
# Successfully downloaded 54209 tweets
# Successfully downloaded 54309 tweets
# Successfully downloaded 54409 tweets
# Successfully downloaded 54509 tweets
# Successfully downloaded 54609 tweets
# Successfully downloaded 54709 tweets
# Successfully downloaded 54809 tweets
# Successfully downloaded 54909 tweets
# Successfully downloaded 55009 tweets
# Successfully downloaded 55109 tweets
# Successfully downloaded 55209 tweets
# Successfully downloaded 55309 tweets
# Successfully downloaded 55409 tweets
# Successfully downloaded 55509 tweets
# Successfully downloaded 55609 tweets
# Successfully downloaded 55709 tweets
# Successfully downloaded 55809 tweets
# Successfully downloaded 55909 tweets
# Successfully downloaded 56009 tweets
# Successfully downloaded 56109 tweets
# Successfully downloaded 56209 tweets
# Successfully downloaded 56309 tweets
# Successfully downloaded 56409 tweets
# Successfully downloaded 56509 tweets
# Successfully downloaded 56609 tweets
# Successfully downloaded 56709 tweets
# Successfully downloaded 56809 tweets
# Successfully downloaded 56909 tweets
# Successfully downloaded 57009 tweets
# Successfully downloaded 57109 tweets
# Successfully downloaded 57209 tweets
# Successfully downloaded 57309 tweets
# Successfully downloaded 57409 tweets
# Successfully downloaded 57509 tweets
# Successfully downloaded 57609 tweets
# Successfully downloaded 57709 tweets
# Successfully downloaded 57809 tweets
# Successfully downloaded 57909 tweets
# Successfully downloaded 58009 tweets
# Successfully downloaded 58109 tweets
# Successfully downloaded 58209 tweets
# Successfully downloaded 58309 tweets
# Successfully downloaded 58409 tweets
# Successfully downloaded 58509 tweets
# Successfully downloaded 58609 tweets
# Successfully downloaded 58709 tweets
# Successfully downloaded 58809 tweets
# Successfully downloaded 58909 tweets
# Successfully downloaded 59009 tweets
# Successfully downloaded 59109 tweets
# Successfully downloaded 59209 tweets
# Successfully downloaded 59309 tweets
# Successfully downloaded 59409 tweets
# Successfully downloaded 59507 tweets
# Successfully downloaded 59605 tweets
# Successfully downloaded 59703 tweets
# Successfully downloaded 59801 tweets
# Successfully downloaded 59899 tweets
# Successfully downloaded 59997 tweets
# Successfully downloaded 60095 tweets
# Successfully downloaded 60193 tweets
# Successfully downloaded 60291 tweets
# Successfully downloaded 60389 tweets
# Successfully downloaded 60487 tweets
# Successfully downloaded 60585 tweets
# Successfully downloaded 60683 tweets
# Successfully downloaded 60781 tweets
# Successfully downloaded 60879 tweets
# Successfully downloaded 60977 tweets
# Successfully downloaded 61075 tweets
# Successfully downloaded 61173 tweets
# Successfully downloaded 61271 tweets
# Successfully downloaded 61369 tweets
# Successfully downloaded 61467 tweets
# Successfully downloaded 61565 tweets
# Successfully downloaded 61663 tweets
# Successfully downloaded 61761 tweets
# Successfully downloaded 61859 tweets
# Successfully downloaded 61957 tweets
# Successfully downloaded 62055 tweets
# Successfully downloaded 62153 tweets
# Successfully downloaded 62251 tweets
# Successfully downloaded 62349 tweets
# Successfully downloaded 62447 tweets
# Successfully downloaded 62545 tweets
# Successfully downloaded 62643 tweets
# Successfully downloaded 62741 tweets
# Successfully downloaded 62839 tweets
# Successfully downloaded 62937 tweets
# Successfully downloaded 63035 tweets
# Successfully downloaded 63133 tweets
# Successfully downloaded 63231 tweets
# Successfully downloaded 63329 tweets
# Successfully downloaded 63427 tweets
# Successfully downloaded 63525 tweets
# Successfully downloaded 63623 tweets
# Successfully downloaded 63721 tweets
# Successfully downloaded 63819 tweets
# Successfully downloaded 63917 tweets
# Successfully downloaded 64015 tweets
# Successfully downloaded 64113 tweets
# Successfully downloaded 64211 tweets
# Successfully downloaded 64309 tweets
# Successfully downloaded 64407 tweets
# Successfully downloaded 64505 tweets
# Successfully downloaded 64603 tweets
# Successfully downloaded 64701 tweets
# Successfully downloaded 64799 tweets
# Successfully downloaded 64897 tweets
# Successfully downloaded 64995 tweets
# Successfully downloaded 65093 tweets
# Successfully downloaded 65191 tweets
# Successfully downloaded 65289 tweets
# Successfully downloaded 65387 tweets
# Successfully downloaded 65485 tweets
# Successfully downloaded 65583 tweets
# Successfully downloaded 65681 tweets
# Successfully downloaded 65779 tweets
# Successfully downloaded 65877 tweets
# Successfully downloaded 65975 tweets
# Successfully downloaded 66073 tweets
# Successfully downloaded 66171 tweets
# Successfully downloaded 66269 tweets
# Successfully downloaded 66367 tweets
# Successfully downloaded 66465 tweets
# Successfully downloaded 66563 tweets
# Successfully downloaded 66661 tweets
# Successfully downloaded 66759 tweets
# Successfully downloaded 66857 tweets
# Successfully downloaded 66955 tweets
# Successfully downloaded 67053 tweets
# Successfully downloaded 67151 tweets
# Successfully downloaded 67249 tweets
# Successfully downloaded 67347 tweets
# Successfully downloaded 67445 tweets
# Successfully downloaded 67543 tweets
# Successfully downloaded 67641 tweets
# Successfully downloaded 67739 tweets
# Successfully downloaded 67837 tweets
# Successfully downloaded 67935 tweets
# Successfully downloaded 68033 tweets
# Successfully downloaded 68131 tweets
# Successfully downloaded 68229 tweets
# Successfully downloaded 68327 tweets
# Successfully downloaded 68425 tweets
# Successfully downloaded 68523 tweets
# Successfully downloaded 68621 tweets
# Successfully downloaded 68719 tweets
# Successfully downloaded 68817 tweets
# Successfully downloaded 68915 tweets
# Successfully downloaded 69013 tweets
# Successfully downloaded 69104 tweets
# Successfully downloaded 69195 tweets
# Successfully downloaded 69286 tweets
# Successfully downloaded 69377 tweets
# Successfully downloaded 69468 tweets
# Successfully downloaded 69559 tweets
# Successfully downloaded 69650 tweets
# Successfully downloaded 69741 tweets
# Successfully downloaded 69832 tweets
# Successfully downloaded 69923 tweets
# Successfully downloaded 70014 tweets
# Successfully downloaded 70105 tweets
# Successfully downloaded 70196 tweets
# Successfully downloaded 70287 tweets
# Successfully downloaded 70378 tweets
# Successfully downloaded 70469 tweets
# Successfully downloaded 70560 tweets
# Successfully downloaded 70651 tweets
# Successfully downloaded 70742 tweets
# Successfully downloaded 70833 tweets
# Successfully downloaded 70924 tweets
# Successfully downloaded 71015 tweets
# Successfully downloaded 71106 tweets
# Successfully downloaded 71197 tweets
# Successfully downloaded 71288 tweets
# Successfully downloaded 71379 tweets
# Successfully downloaded 71470 tweets
# Successfully downloaded 71561 tweets
# Successfully downloaded 71652 tweets
# Successfully downloaded 71743 tweets
# Successfully downloaded 71834 tweets
# Successfully downloaded 71925 tweets
# Successfully downloaded 72016 tweets
# Successfully downloaded 72107 tweets
# Successfully downloaded 72198 tweets
# Successfully downloaded 72289 tweets
# Successfully downloaded 72380 tweets
# Successfully downloaded 72471 tweets
# Successfully downloaded 72562 tweets
# Successfully downloaded 72653 tweets
# Successfully downloaded 72744 tweets
# Successfully downloaded 72835 tweets
# Successfully downloaded 72926 tweets
# Successfully downloaded 73017 tweets
# Successfully downloaded 73108 tweets
# Successfully downloaded 73199 tweets
# Successfully downloaded 73290 tweets
# Successfully downloaded 73381 tweets
# Successfully downloaded 73472 tweets
# Successfully downloaded 73563 tweets
# Successfully downloaded 73654 tweets
# Successfully downloaded 73745 tweets
# Successfully downloaded 73836 tweets
# Successfully downloaded 73927 tweets
# Successfully downloaded 74018 tweets
# Successfully downloaded 74109 tweets
# Successfully downloaded 74200 tweets
# Successfully downloaded 74291 tweets
# Successfully downloaded 74382 tweets
# Successfully downloaded 74473 tweets
# Successfully downloaded 74564 tweets
# Successfully downloaded 74655 tweets
# Successfully downloaded 74746 tweets
# Successfully downloaded 74837 tweets
# Successfully downloaded 74928 tweets
# Successfully downloaded 75019 tweets
# Successfully downloaded 75110 tweets
# Successfully downloaded 75201 tweets
# Successfully downloaded 75292 tweets
# Successfully downloaded 75383 tweets
# Successfully downloaded 75474 tweets
# Successfully downloaded 75565 tweets
# Successfully downloaded 75656 tweets
# Successfully downloaded 75747 tweets
# Successfully downloaded 75838 tweets
# Successfully downloaded 75929 tweets
# Successfully downloaded 76020 tweets
# Successfully downloaded 76111 tweets
# Successfully downloaded 76202 tweets
# Successfully downloaded 76293 tweets
# Successfully downloaded 76384 tweets
# Successfully downloaded 76475 tweets
# Successfully downloaded 76566 tweets
# Successfully downloaded 76657 tweets
# Successfully downloaded 76748 tweets
# Successfully downloaded 76839 tweets
# Successfully downloaded 76930 tweets
# Successfully downloaded 77021 tweets
# Successfully downloaded 77112 tweets
# Successfully downloaded 77203 tweets
# Successfully downloaded 77294 tweets
# Successfully downloaded 77394 tweets
# Successfully downloaded 77494 tweets
# Successfully downloaded 77594 tweets
# Successfully downloaded 77694 tweets
# Successfully downloaded 77794 tweets
# Successfully downloaded 77894 tweets
# Successfully downloaded 77994 tweets
# Successfully downloaded 78094 tweets
# Successfully downloaded 78194 tweets
# Successfully downloaded 78294 tweets
# Successfully downloaded 78394 tweets
# Successfully downloaded 78494 tweets
# Successfully downloaded 78594 tweets
# Successfully downloaded 78694 tweets
# Successfully downloaded 78794 tweets
# Successfully downloaded 78894 tweets
# Successfully downloaded 78994 tweets
# Successfully downloaded 79094 tweets
# Successfully downloaded 79194 tweets
# Successfully downloaded 79294 tweets
# Successfully downloaded 79394 tweets
# Successfully downloaded 79494 tweets
# Successfully downloaded 79594 tweets
# Successfully downloaded 79694 tweets
# Successfully downloaded 79794 tweets
# Successfully downloaded 79894 tweets
# Successfully downloaded 79994 tweets
# Successfully downloaded 80094 tweets
# Successfully downloaded 80194 tweets
# Successfully downloaded 80294 tweets
# Successfully downloaded 80394 tweets
# Successfully downloaded 80494 tweets
# Successfully downloaded 80594 tweets
# Successfully downloaded 80694 tweets
# Successfully downloaded 80794 tweets
# Successfully downloaded 80894 tweets
# Successfully downloaded 80994 tweets
# Successfully downloaded 81094 tweets
# Successfully downloaded 81194 tweets
# Successfully downloaded 81294 tweets
# Successfully downloaded 81394 tweets
# Successfully downloaded 81494 tweets
# Successfully downloaded 81594 tweets
# Successfully downloaded 81694 tweets
# Successfully downloaded 81794 tweets
# Successfully downloaded 81894 tweets
# Successfully downloaded 81994 tweets
# Successfully downloaded 82094 tweets
# Successfully downloaded 82194 tweets
# Successfully downloaded 82294 tweets
# Successfully downloaded 82394 tweets
# Successfully downloaded 82494 tweets
# Successfully downloaded 82594 tweets
# Successfully downloaded 82694 tweets
# Successfully downloaded 82794 tweets
# Successfully downloaded 82894 tweets
# Successfully downloaded 82994 tweets
# Successfully downloaded 83094 tweets
# Successfully downloaded 83194 tweets
# Successfully downloaded 83294 tweets
# Successfully downloaded 83394 tweets
# Successfully downloaded 83494 tweets
# Successfully downloaded 83594 tweets
# Successfully downloaded 83694 tweets
# Successfully downloaded 83794 tweets
# Successfully downloaded 83894 tweets
# Successfully downloaded 83994 tweets
# Successfully downloaded 84094 tweets
# Successfully downloaded 84194 tweets
# Successfully downloaded 84294 tweets
# Successfully downloaded 84394 tweets
# Successfully downloaded 84494 tweets
# Successfully downloaded 84594 tweets
# Successfully downloaded 84694 tweets
# Successfully downloaded 84794 tweets
# Successfully downloaded 84894 tweets
# Successfully downloaded 84994 tweets
# Successfully downloaded 85094 tweets
# Successfully downloaded 85194 tweets
# Successfully downloaded 85294 tweets
# Successfully downloaded 85394 tweets
# Successfully downloaded 85494 tweets
# Successfully downloaded 85594 tweets
# Successfully downloaded 85694 tweets
# Successfully downloaded 85794 tweets
# Successfully downloaded 85894 tweets
# Successfully downloaded 85994 tweets
# Successfully downloaded 86094 tweets
# Successfully downloaded 86194 tweets
# Successfully downloaded 86294 tweets
# Successfully downloaded 86394 tweets
# Successfully downloaded 86494 tweets
# Successfully downloaded 86594 tweets
# Successfully downloaded 86694 tweets
# Successfully downloaded 86794 tweets
# Successfully downloaded 86894 tweets
# Successfully downloaded 86994 tweets
# Successfully downloaded 87094 tweets
# Successfully downloaded 87194 tweets
# Successfully downloaded 87294 tweets
# Successfully downloaded 87394 tweets
# Successfully downloaded 87494 tweets
# Successfully downloaded 87594 tweets
# Successfully downloaded 87694 tweets
# Successfully downloaded 87794 tweets
# Successfully downloaded 87894 tweets
# Successfully downloaded 87994 tweets
# Successfully downloaded 88094 tweets
# Successfully downloaded 88194 tweets
# Successfully downloaded 88294 tweets
# Successfully downloaded 88394 tweets
# Successfully downloaded 88494 tweets
# Successfully downloaded 88594 tweets
# Successfully downloaded 88694 tweets
# Successfully downloaded 88794 tweets
# Successfully downloaded 88894 tweets
# Successfully downloaded 88994 tweets
# Successfully downloaded 89094 tweets
# Successfully downloaded 89194 tweets
# Successfully downloaded 89294 tweets
# Successfully downloaded 89394 tweets
# Successfully downloaded 89494 tweets
# Successfully downloaded 89594 tweets
# Successfully downloaded 89694 tweets
# Successfully downloaded 89794 tweets
# Successfully downloaded 89894 tweets
# Successfully downloaded 89994 tweets
# Successfully downloaded 90094 tweets
# Successfully downloaded 90194 tweets
# Successfully downloaded 90294 tweets
# Successfully downloaded 90394 tweets
# Successfully downloaded 90494 tweets
# Successfully downloaded 90594 tweets
# Successfully downloaded 90694 tweets
# Successfully downloaded 90794 tweets
# Successfully downloaded 90894 tweets
# Successfully downloaded 90994 tweets
# Successfully downloaded 91094 tweets
# Successfully downloaded 91194 tweets
# Successfully downloaded 91294 tweets
# Successfully downloaded 91394 tweets
# Successfully downloaded 91494 tweets
# Successfully downloaded 91594 tweets
# Successfully downloaded 91694 tweets
# Successfully downloaded 91794 tweets
# Successfully downloaded 91894 tweets
# Successfully downloaded 91994 tweets
# Successfully downloaded 92094 tweets
# Successfully downloaded 92194 tweets
# Successfully downloaded 92294 tweets
# Successfully downloaded 92394 tweets
# Successfully downloaded 92494 tweets
# Successfully downloaded 92594 tweets
# Successfully downloaded 92694 tweets
# Successfully downloaded 92794 tweets
# Successfully downloaded 92894 tweets
# Successfully downloaded 92994 tweets
# Successfully downloaded 93094 tweets
# Successfully downloaded 93194 tweets
# Successfully downloaded 93294 tweets
# Successfully downloaded 93394 tweets
# Successfully downloaded 93494 tweets
# Successfully downloaded 93594 tweets
# Successfully downloaded 93694 tweets
# Successfully downloaded 93794 tweets
# Successfully downloaded 93894 tweets
# Successfully downloaded 93994 tweets
# Successfully downloaded 94094 tweets
# Successfully downloaded 94194 tweets
# Successfully downloaded 94294 tweets
# Successfully downloaded 94394 tweets
# Successfully downloaded 94494 tweets
# Successfully downloaded 94594 tweets
# Successfully downloaded 94694 tweets
# Successfully downloaded 94794 tweets
# Successfully downloaded 94894 tweets
# Successfully downloaded 94994 tweets
# Successfully downloaded 95094 tweets
# Successfully downloaded 95194 tweets
# Successfully downloaded 95294 tweets
# Successfully downloaded 95394 tweets
# Successfully downloaded 95494 tweets
# Successfully downloaded 95594 tweets
# Successfully downloaded 95694 tweets
# Successfully downloaded 95794 tweets
# Successfully downloaded 95894 tweets
# Successfully downloaded 95994 tweets
# Successfully downloaded 96094 tweets
# Successfully downloaded 96194 tweets
# Successfully downloaded 96294 tweets
# Successfully downloaded 96394 tweets
# Successfully downloaded 96494 tweets
# Successfully downloaded 96594 tweets
# Successfully downloaded 96694 tweets
# Successfully downloaded 96794 tweets
# Successfully downloaded 96894 tweets
# Successfully downloaded 96994 tweets
# Successfully downloaded 97094 tweets
# Successfully downloaded 97194 tweets
# Successfully downloaded 97294 tweets
# Successfully downloaded 97394 tweets
# Successfully downloaded 97494 tweets
# Successfully downloaded 97594 tweets
# Successfully downloaded 97694 tweets
# Successfully downloaded 97794 tweets
# Successfully downloaded 97894 tweets
# Successfully downloaded 97994 tweets
# Successfully downloaded 98094 tweets
# Successfully downloaded 98194 tweets
# Successfully downloaded 98294 tweets
# Successfully downloaded 98394 tweets
# Successfully downloaded 98494 tweets
# Successfully downloaded 98594 tweets
# Successfully downloaded 98694 tweets
# Successfully downloaded 98794 tweets
# Successfully downloaded 98894 tweets
# Successfully downloaded 98994 tweets
# Successfully downloaded 99094 tweets
# Successfully downloaded 99194 tweets
# Successfully downloaded 99294 tweets
# Successfully downloaded 99394 tweets
# Successfully downloaded 99494 tweets
# Successfully downloaded 99594 tweets
# Successfully downloaded 99694 tweets
# Successfully downloaded 99794 tweets
# Successfully downloaded 99894 tweets
# Successfully downloaded 99994 tweets
# Successfully downloaded 100094 tweets
# Successfully downloaded 100194 tweets
# Successfully downloaded 100294 tweets
# Successfully downloaded 100394 tweets
# Successfully downloaded 100494 tweets
# Successfully downloaded 100594 tweets
# Successfully downloaded 100694 tweets
# Successfully downloaded 100794 tweets
# Successfully downloaded 100894 tweets
# Successfully downloaded 100994 tweets
# Successfully downloaded 101094 tweets
# Successfully downloaded 101194 tweets
# Successfully downloaded 101294 tweets
# Successfully downloaded 101394 tweets
# Successfully downloaded 101494 tweets
# Successfully downloaded 101594 tweets
# Successfully downloaded 101694 tweets
# Successfully downloaded 101794 tweets
# Successfully downloaded 101894 tweets
# Successfully downloaded 101994 tweets
# Successfully downloaded 102094 tweets
# Successfully downloaded 102194 tweets
# Successfully downloaded 102294 tweets
# Successfully downloaded 102394 tweets
# Successfully downloaded 102494 tweets
# Successfully downloaded 102594 tweets
# Successfully downloaded 102694 tweets
# Successfully downloaded 102794 tweets
# Successfully downloaded 102894 tweets
# Successfully downloaded 102994 tweets
# Successfully downloaded 103094 tweets
# Successfully downloaded 103194 tweets
# Successfully downloaded 103294 tweets
# Successfully downloaded 103394 tweets
# Successfully downloaded 103494 tweets
# Successfully downloaded 103594 tweets
# Successfully downloaded 103694 tweets
# Successfully downloaded 103794 tweets
# Successfully downloaded 103894 tweets
# Successfully downloaded 103994 tweets
# Successfully downloaded 104094 tweets
# Successfully downloaded 104194 tweets
# Successfully downloaded 104294 tweets
# Successfully downloaded 104394 tweets
# Successfully downloaded 104494 tweets
# Successfully downloaded 104594 tweets
# Successfully downloaded 104694 tweets
# Successfully downloaded 104794 tweets
# Successfully downloaded 104894 tweets
# Successfully downloaded 104994 tweets
# Successfully downloaded 105094 tweets
# Successfully downloaded 105194 tweets
# Successfully downloaded 105294 tweets
# Successfully downloaded 105394 tweets
# Successfully downloaded 105494 tweets
# Successfully downloaded 105594 tweets
# Successfully downloaded 105694 tweets
# Successfully downloaded 105794 tweets
# Successfully downloaded 105894 tweets
# Successfully downloaded 105994 tweets
# Successfully downloaded 106094 tweets
# Successfully downloaded 106194 tweets
# Successfully downloaded 106294 tweets
# Successfully downloaded 106394 tweets
# Successfully downloaded 106494 tweets
# Successfully downloaded 106594 tweets
# Successfully downloaded 106694 tweets
# Successfully downloaded 106794 tweets
# Successfully downloaded 106894 tweets
# Successfully downloaded 106994 tweets
# Successfully downloaded 107094 tweets
# Successfully downloaded 107194 tweets
# Successfully downloaded 107294 tweets
# A total of 107294 tweets are downloaded and saved to co.txt
# Total time taken is  54.24674034118652 seconds.

# %%
import json
import csv


f = open('s.csv','a',encoding='utf-8')
csvWriter = csv.writer(f)
headers=['full_text','retweet_count','user_followers_count','favorite_count','place','coordinates','geo','created_at','id_str']
csvWriter.writerow(headers)

for inputFile in ['co.txt']:#all the text-file names you want to convert to Csv in the sae folder as this code
    tweets = []
    for line in open(inputFile, 'r'):
        tweets.append(json.loads(line))

    print('#sh',len(tweets))
    count_lines=0
    for tweet in tweets:
        try:
            csvWriter.writerow([tweet['full_text'],tweet['retweet_count'],tweet['user']['followers_count'],tweet['favorite_count'],tweet['place'],tweet['coordinates'],tweet['geo'],tweet['created_at'],str(tweet['id_str'])])
            count_lines+=1
        except Exception as e:
            print(e)
    print(count_lines)
# Out:
# #sh 1086
# 1086

# %%
import re
import pandas as pd
import numpy as np
df = pd.read_csv('s.csv')
df.head(5)
# Out:
#                                            full_text  retweet_count  \
# 0  RT @seawatch_intl: "#COVID19 is not an excuse ...             44
# 1  RT @Dindigulmemes: #BreakingNews \r\n\r\nToday...             10
# 2  Today June 22:  120,000 confirmed deaths\r\n\r...              0
# 3  RT @OrangeCoSheriff: #COVID19 numbers continue...             10
# 4  RT @hildevautmans: Reciprocity in #trade relat...            378
#
#    user_followers_count  favorite_count place coordinates  geo  \
# 0                     0               0   NaN         NaN  NaN
# 1                   280               0   NaN         NaN  NaN
# 2                  1935               0   NaN         NaN  NaN
# 3                  3146               0   NaN         NaN  NaN
# 4                     5               0   NaN         NaN  NaN
#
#                        created_at               id_str
# 0  Tue Jun 23 03:17:52 +0000 2020  1275266798439579653
# 1  Tue Jun 23 03:17:52 +0000 2020  1275266798204497920
# 2  Tue Jun 23 03:17:51 +0000 2020  1275266795276865537
# 3  Tue Jun 23 03:17:51 +0000 2020  1275266791636217856
# 4  Tue Jun 23 03:17:50 +0000 2020  1275266791090950145

# %%
print(len(df.index))
serlis=df.duplicated().tolist()
print(serlis.count(True))
serlis=df.duplicated(['full_text']).tolist()
print(serlis.count(True))
# Out:
# 1052
# 0
# 342

# %%
df=df.drop_duplicates(['full_text'])

# %%
print(df['geo'].isna().sum())
print(df['place'].isna().sum())
print(df['coordinates'].isna().sum())
# Out:
# 709
# 701
# 709

# %%
df=df.drop(['place','coordinates','geo','id_str'],axis=1)
df.head(5)
# Out:
#                                            full_text  retweet_count  \
# 0  RT @seawatch_intl: "#COVID19 is not an excuse ...             44
# 1  RT @Dindigulmemes: #BreakingNews \r\n\r\nToday...             10
# 2  Today June 22:  120,000 confirmed deaths\r\n\r...              0
# 3  RT @OrangeCoSheriff: #COVID19 numbers continue...             10
# 4  RT @hildevautmans: Reciprocity in #trade relat...            378
#
#    user_followers_count  favorite_count                      created_at
# 0                     0               0  Tue Jun 23 03:17:52 +0000 2020
# 1                   280               0  Tue Jun 23 03:17:52 +0000 2020
# 2                  1935               0  Tue Jun 23 03:17:51 +0000 2020
# 3                  3146               0  Tue Jun 23 03:17:51 +0000 2020
# 4                     5               0  Tue Jun 23 03:17:50 +0000 2020

# %%
import pandas as pd
df = pd.read_csv('s.csv')
#full_text is fine

df_copy = df
print(len(df_copy))
serlis=df_copy.duplicated().tolist()
print(serlis.count(True)) #7479

serlis=df_copy.duplicated(['full_text']).tolist()
print(serlis.count(True))
# Out:
# 1052
# 0
# 342

# %%
import re
for i in range(len(df)):
    txt = df.loc[i]["full_text"]
    txt=re.sub(r'@[A-Z0-9a-z_:]+','',txt)#replace username-tags
    txt=re.sub(r'^[RT]+','',txt)#replace RT-tags
    txt = re.sub('https?://[A-Za-z0-9./]+','',txt)#replace URLs
    txt=re.sub("[^a-zA-Z]", " ",txt)#replace hashtags
    df.at[i,"full_text"]=txt

# %%
for i in range(len(df_copy.index)):
        text = df_copy.loc[i]['full_text']
        tokens = nltk.word_tokenize(text)
        tagged_sent = pos_tag(tokens)
        store_it = [(word, map_tag('en-ptb', 'universal', tag)) for word, tag in tagged_sent]

# %%
import pandas as pd
import re
import time
import nltk
from nltk.corpus import sentiwordnet as swn
from nltk.tag import pos_tag,map_tag
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

pstem = PorterStemmer()
lem = WordNetLemmatizer()
stop_words = stopwords.words('english')

def clean_df(df_copy):
    
    #DROPS
    #CHOOSE EITHER TO DROP ALL-ROW DUPLICATES OR FULL_TEXT DUPLICATES
    df_copy=df_copy.drop_duplicates(['full_text']) #3377 left after this
    df_copy=df_copy.reset_index(drop=True)
    df_copy=df_copy.drop(['place','coordinates','geo','id_str'],axis=1)
    #df_copy=
    
    # BASIC CLEANING FUNCTION
    for i in range(len(df_copy)):
        txt = df_copy.loc[i]["full_text"]
        txt=re.sub(r'@[A-Z0-9a-z_:]+','',txt)#username-tags
        txt=re.sub(r'^[RT]+','',txt)#RT-tags
        txt = re.sub('https?://[A-Za-z0-9./]+','',txt)#URLs
        txt=re.sub("[^a-zA-Z]", " ",txt)#hashtags
        df_copy.at[i,"full_text"]=txt
    #POS-TAGGING AND SENTIMENT SCORE
    li_swn=[]
    li_swn_pos=[]
    li_swn_neg=[]
    missing_words=[]
    for i in range(len(df_copy.index)):
        text = df_copy.loc[i]['full_text']
        tokens = nltk.word_tokenize(text)
        tagged_sent = pos_tag(tokens)
        store_it = [(word, map_tag('en-ptb', 'universal', tag)) for word, tag in tagged_sent]
        #print("Tagged Parts of Speech:",store_it)

        pos_total=0
        neg_total=0
        for word,tag in store_it:
            if(tag=='NOUN'):
                tag='n'
            elif(tag=='VERB'):
                tag='v'
            elif(tag=='ADJ'):
                tag='a'
            elif(tag=='ADV'):
                tag = 'r'
            else:
                tag='nothing'

            if(tag!='nothing'):   
                concat = word+'.'+tag+'.01'
                try:
                    this_word_pos=swn.senti_synset(concat).pos_score()
                    this_word_neg=swn.senti_synset(concat).neg_score()
                    #print(word,tag,':',this_word_pos,this_word_neg)
                except Exception as e:
                    wor = lem.lemmatize(word)
                    concat = wor+'.'+tag+'.01'
                    # Checking if there's a possiblity of lemmatized word be accepted into SWN corpus
                    try:
                        this_word_pos=swn.senti_synset(concat).pos_score()
                        this_word_neg=swn.senti_synset(concat).neg_score()
                    except Exception as e:
                        wor = pstem.stem(word)
                        concat = wor+'.'+tag+'.01'
                        # Checking if there's a possiblity of lemmatized word be accepted
                        try:
                            this_word_pos=swn.senti_synset(concat).pos_score()
                            this_word_neg=swn.senti_synset(concat).neg_score()
                        except:
                            missing_words.append(word) 
                            continue
                pos_total+=this_word_pos
                neg_total+=this_word_neg
        li_swn_pos.append(pos_total)
        li_swn_neg.append(neg_total)

        if(pos_total!=0 or neg_total!=0):
            if(pos_total>neg_total):
                li_swn.append(1)
            else:
                li_swn.append(-1)
        else:
            li_swn.append(0)
    # end-of pos-tagging&sentiment
    
    #3-rd for loop    
    #LEMMATIZING,STEMMING,STOP-WORDS
    for i in range(len(df_copy.index)):
        text = df_copy.loc[i]['full_text']
        tokens = nltk.word_tokenize(text)
        tokens = [word for word in tokens if word not in stop_words]

        for j in range(len(tokens)):
            tokens[j] = lem.lemmatize(tokens[j])
            tokens[j] = pstem.stem(tokens[j])

        tokens_sent=' '.join(tokens)
        df_copy.at[i,"full_text"] = tokens_sent
        
    df_copy.insert(5,"pos_score",li_swn_pos,True)
    df_copy.insert(6,"neg_score",li_swn_neg,True)
    df_copy.insert(7,"sent_score",li_swn,True)
    
    
    
    return df_copy

st=time.time()
df_copy = clean_df(df_copy)
end=time.time()

# df_copy.loc[4]
print(end-st)#
# df_copy
# takes(no senti) 0.7440352439880371 with txt less..so go with it
# takes(no senti) 3.600219488143921 with df_copy.loc
# Out:
# 24.039987564086914

# %%
df_copy
# Out:
#                                              full_text  retweet_count  \
# 0    covid excus let peopl drown sea excus countri ...             44
# 1    breakingnew today positv case dindigul covid d...             10
# 2    oday june confirm death hane april max end jun...              0
# 3    covid number continu rise pleas continu practi...             10
# 4    reciproc trade relat independ investig respons...            378
# ..                                                 ...            ...
# 694  here situat covid NC the biggest number everyo...            170
# 695  the medium want control covid exit the medium ...              2
# 696  start tomorrow tue june public applic covid re...              3
# 697  now quit visibl part difficult decis make natu...              0
# 698  mizoram No new covid posit found last hr out s...              0
#
#      user_followers_count  favorite_count                      created_at  \
# 0                       0               0  Tue Jun 23 03:17:52 +0000 2020
# 1                     280               0  Tue Jun 23 03:17:52 +0000 2020
# 2                    1935               0  Tue Jun 23 03:17:51 +0000 2020
# 3                    3146               0  Tue Jun 23 03:17:51 +0000 2020
# 4                       5               0  Tue Jun 23 03:17:50 +0000 2020
# ..                    ...             ...                             ...
# 694                   658               0  Tue Jun 23 03:09:21 +0000 2020
# 695                   748               0  Tue Jun 23 03:09:21 +0000 2020
# 696                   284               0  Tue Jun 23 03:09:20 +0000 2020
# 697                  3880               2  Tue Jun 23 03:09:18 +0000 2020
# 698                   439               2  Tue Jun 23 03:09:18 +0000 2020
#
#      pos_score  neg_score  sent_score
# 0        0.000      1.750          -1
# 1        0.125      0.000           1
# 2        0.750      1.625          -1
# 3        0.875      0.125           1
# 4        0.125      0.000           1
# ..         ...        ...         ...
# 694      0.375      0.375          -1
# 695      0.875      0.000           1
# 696      0.375      0.625          -1
# 697      1.000      2.125          -1
# 698      2.000      2.875          -1
#
# [699 rows x 8 columns]

# %%
df_copy.to_csv('h.csv',index=False)

# %%
import pandas as pd
df_copy = pd.read_csv('h.csv',index_col=False)
df_copy.head
# Out:
# <bound method NDFrame.head of                                              full_text  retweet_count  \
# 0    covid excus let peopl drown sea excus countri ...             44
# 1    breakingnew today positv case dindigul covid d...             10
# 2    oday june confirm death hane april max end jun...              0
# 3    covid number continu rise pleas continu practi...             10
# 4    reciproc trade relat independ investig respons...            378
# ..                                                 ...            ...
# 694  here situat covid NC the biggest number everyo...            170
# 695  the medium want control covid exit the medium ...              2
# 696  start tomorrow tue june public applic covid re...              3
# 697  now quit visibl part difficult decis make natu...              0
# 698  mizoram No new covid posit found last hr out s...              0
#
#      user_followers_count  favorite_count                      created_at  \
# 0                       0               0  Tue Jun 23 03:17:52 +0000 2020
# 1                     280               0  Tue Jun 23 03:17:52 +0000 2020
# 2                    1935               0  Tue Jun 23 03:17:51 +0000 2020
# 3                    3146               0  Tue Jun 23 03:17:51 +0000 2020
# 4                       5               0  Tue Jun 23 03:17:50 +0000 2020
# ..                    ...             ...                             ...
# 694                   658               0  Tue Jun 23 03:09:21 +0000 2020
# 695                   748               0  Tue Jun 23 03:09:21 +0000 2020
# 696                   284               0  Tue Jun 23 03:09:20 +0000 2020
# 697                  3880               2  Tue Jun 23 03:09:18 +0000 2020
# 698                   439               2  Tue Jun 23 03:09:18 +0000 2020
#
#      pos_score  neg_score  sent_score
# 0        0.000      1.750          -1
# 1        0.125      0.000           1
# 2        0.750      1.625          -1
# 3        0.875      0.125           1
# 4        0.125      0.000           1
# ..         ...        ...         ...
# 694      0.375      0.375          -1
# 695      0.875      0.000           1
# 696      0.375      0.625          -1
# 697      1.000      2.125          -1
# 698      2.000      2.875          -1
#
# [699 rows x 8 columns]>
